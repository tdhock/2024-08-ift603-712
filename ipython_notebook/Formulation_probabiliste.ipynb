# %%
# %pylab inline
import matplotlib.pyplot as plot
import numpy as np
x = np.random.randn(100000)   # Génère 100000 échantillons d'une Gaussienne N(x|0,1)
dummy = plot.hist(x,100)
print ("moyenne=",mean(x))
print ("variance=",var(x))
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# moyenne= -0.0006623915458671157
# variance= 1.0044593395775572

# %%
y = 2*x - 1 # Transforme les échantillons linéairement
dummy = plot.hist(y,100)
print ("moyenne=",mean(y))    # Devrait être autour de 2*E[x] -1 = -1
print ("variance=",var(y))    # Devrait êter autour de 2**2 * var[x] = 4
# Out:
# moyenne= -1.0013247830917342
# variance= 4.017837358310229

# %%
mu = np.array([0,0])
sigma = np.eye(2)
x = np.random.multivariate_normal(mu,sigma,100000).T # Génère 100000 échantillons d'une Gaussienne N(x|0,I) en 2 dimensions
dummy = plot.hist2d(x[0,:],x[1,:],50,cmap = cm.Greys)
axis('equal')
print ("moyenne=",x.mean(axis=1))
print ("covariance=\n",cov(x))
# Out:
# moyenne= [0.00081923 0.00156184]
# covariance=
#  [[ 1.00387505 -0.00169707]
#  [-0.00169707  0.99666667]]

# %%
mu = np.array([1,2])
sigma = np.array([[2,0],[0,1]])
y = np.random.multivariate_normal(mu,sigma,100000).T # Génère 100000 échantillons d'une Gaussienne N(x|[1,2]^T,[[2,0],[0,1]]) en 2 dimensions
dummy = plot.hist2d(y[0,:],y[1,:],50,cmap = cm.Greys)
axis('equal')
print("moyenne=",y.mean(axis=1))
print("covariance=\n",cov(y))
# Out:
# moyenne= [1.00115525 2.00393683]
# covariance=
#  [[ 2.01850572 -0.00466253]
#  [-0.00466253  0.99280099]]

# %%
mu = np.array([1,2])
sigma = np.array([[1.5,1],[1,1.5]])
y = np.random.multivariate_normal(mu,sigma,100000).T # Génère 100000 échantillons d'une Gaussienne N(x|[1,2]^T,[[1.5,1],[1,1.5]]) en 2 dimensions
dummy = plot.hist2d(y[0,:],y[1,:],50,cmap = cm.Greys)
axis('equal')
print("moyenne=",y.mean(axis=1))
print("covariance=\n",np.cov(y))
# Out:
# moyenne= [1.00321535 1.99941577]
# covariance=
#  [[1.50293479 0.99984436]
#  [0.99984436 1.50541265]]

# %%
mu = np.array([2,-1])
A = np.array([[3,0],[0,0.5]])
y = np.dot(A,x) + mu.reshape((2,1))
dummy = plot.hist2d(y[0,:],y[1,:],50,cmap = cm.Greys)
axis('equal')
print("moyenne=",y.mean(axis=1))
print('devrait être',mu)    # E[A x + mu] = A E[x]+mu = A(0)+mu = mu
print("covariance=\n",np.cov(y))
print('devrait être\n',np.dot(A,A.T))   # cov[A x + mu] = A cov[x] A^T = A I A^T = A A^T
# Out:
# moyenne= [ 2.0024577  -0.99921908]
# devrait être [ 2 -1]
# covariance=
#  [[ 9.03487549e+00 -2.54560007e-03]
#  [-2.54560007e-03  2.49166667e-01]]
# devrait être
#  [[9.   0.  ]
#  [0.   0.25]]

# %%
mu = np.array([2,-1])
A = np.array([[2,1],[1,2]])
y = np.dot(A,x) + mu.reshape((2,1))
dummy = plot.hist2d(y[0,:],y[1,:],50,cmap = cm.Greys)
axis('equal')
print("moyenne=",y.mean(axis=1))
print('devrait être',mu)    # E[A x + mu] = A E[x]+mu = A(0)+mu = mu
print("covariance=\n",np.cov(y))
print('devrait être\n',np.dot(A,A.T))   # cov[A x + mu] = A cov[x] A^T = A I A^T = A A^T
# Out:
# moyenne= [ 2.00320031 -0.99605709]
# devrait être [ 2 -1]
# covariance=
#  [[5.00537862 3.99259811]
#  [3.99259811 4.98375347]]
# devrait être
#  [[5 4]
#  [4 5]]
